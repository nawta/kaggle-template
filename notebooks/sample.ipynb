# %%
# %cd ..
# Out:
# /Users/naokimurakami/private/kaggle-template

# %%
from experiments.exp000_sample.run import Config

cfg = Config()
cfg
# Out:
# Config(env=EnvConfig(input_dir='/Users/naokimurakami/private/kaggle-template/input', output_dir='/Users/naokimurakami/private/kaggle-template/output', exp_output_dir='/Users/naokimurakami/private/kaggle-template/output/experiments'), exp=ExpConfig(debug=False, seed=7, learning_rate=0.001, batch_size=32, folds=[0, 1, 2, 3, 4]))

# %%
from pathlib import Path
import os

exp_name = "notebooks/tmp"
output_path = Path(cfg.env.output_dir) / exp_name
print(f"{exp_name=}, {output_path=}")
os.makedirs(output_path, exist_ok=True)
# Out:
# exp_name='notebooks/tmp', output_path=PosixPath('/Users/naokimurakami/private/kaggle-template/output/notebooks/tmp')
